# %% [markdown]
# <a href="https://colab.research.google.com/github/juanicesi1997/Pregunta-S.M.A.R.T/blob/main/Analisis_univariado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Try reading the file with the 'error_bad_lines' parameter set to False to skip problematic lines
df = pd.read_csv('/content/drive/MyDrive/Saber_11__2019-2_20240816.csv')

# If you want to investigate the skipped lines, you can use the 'warn_bad_lines' parameter
# df = pd.read_csv('/content/Saber_11__2019-2_20240816.csv', warn_bad_lines=True)

# Print the shape of the DataFrame to check the number of rows and columns
print(df.shape)
# Out:
# (24805, 82)
# <ipython-input-2-7340d99f1e5e>:7: DtypeWarning: Columns (11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Saber_11__2019-2_20240816.csv')

# %%
columnas_a_mantener = ['PUNT_C_NATURALES']
df_columnas = df[columnas_a_mantener]

# %%
df_columnas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24805 entries, 0 to 24804
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PUNT_C_NATURALES  24804 non-null  float64
# dtypes: float64(1)
# memory usage: 193.9 KB

# %%
df_columnas.isnull().sum()
# Out:
# PUNT_C_NATURALES    1
# dtype: int64

# %%
df_columnas.shape
# Out:
# (24804, 1)

# %%
df_columnas.head()
# Out:
#    PUNT_C_NATURALES
# 0              37.0
# 1              54.0
# 2              41.0
# 3              61.0
# 4              55.0

# %%
df_columnas.tail()
# Out:
#        PUNT_C_NATURALES
# 24799              34.0
# 24800              68.0
# 24801              31.0
# 24802              56.0
# 24803              59.0

# %%
df_columnas.isnull().sum()
# Out:
# PUNT_C_NATURALES    0
# dtype: int64

# %%
df_columnas.describe(include= 'all')
# Out:
#        PUNT_C_NATURALES
# count      24804.000000
# mean          48.122722
# std           10.950830
# min            0.000000
# 25%           40.000000
# 50%           47.000000
# 75%           56.000000
# max          100.000000

# %%
df_columnas.median()
# Out:
# PUNT_C_NATURALES    47.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Histograma para los puntajes de Ciencias Naturales
plt.hist(df_columnas['PUNT_C_NATURALES'], bins=30, edgecolor='red')
plt.title('Distribución de puntajes en Ciencias Naturales')
plt.xlabel('Puntaje')
plt.ylabel('Frecuencia')
plt.show()

# %%
import seaborn as sns
# Boxplot para los puntajes de Ciencias Naturales
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_columnas['PUNT_C_NATURALES'])
plt.title('Diagrama de caja de puntajes en Ciencias Naturales')
plt.xlabel('Puntaje')
plt.ylabel('Puntaje')
plt.show()

# %%
df_columnas.hist(figsize=(10, 10))
plt.show()

# %% [markdown]
# **Analisis de resultados**
#
# En este analisis univariado se va a realizar el analisis del puntaje de las pruebas icfes en colombia del año 2021, estos datos tienen una forma de (24804, 1).
# Despues de realizar el analisis del comoportamiento de los datos se obtuvo que la media de los puntos es alrededor de 48. Por lo cual se puede concluir que las intervenciones enfocadas a los estudiantes por debajo del primer cuartil podrian ser una de las variables a tener en cuenta para mejorar el desempeño en el icfes, en especifico en el area de las ciencias naturales en colombia.

# %% [markdown]
# El análisis univariado de la columna PUNT_C_NATURALES, que mide los resultados en Ciencias Naturales en las pruebas ICFES, revela una media de 48.09 puntos y una desviación estándar de 10.85 puntos. Aunque la mediana es similar a la media, la distribución muestra una concentración de puntajes alrededor del promedio, con pocos valores extremos. Esto indica una tendencia central clara con variabilidad moderada. Las conclusiones sugieren que intervenciones enfocadas en estudiantes con puntajes por debajo del primer cuartil (40.81 puntos) podrían ser clave para mejorar el desempeño general.
