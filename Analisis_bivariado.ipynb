# %% [markdown]
# <a href="https://colab.research.google.com/github/juanicesi1997/Pregunta-S.M.A.R.T/blob/main/Analisis_bivariado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'PERIODO', 'ESTU_CONSECUTIVO',
#        'ESTU_ESTUDIANTE', 'ESTU_TIENEETNIA', 'ESTU_PAIS_RESIDE', 'ESTU_ETNIA',
#        'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_MCPIO_RESIDE',
#        'ESTU_COD_RESIDE_MCPIO', 'FAMI_ESTRATOVIVIENDA', 'FAMI_PERSONASHOGAR',
#        'FAMI_CUARTOSHOGAR', 'FAMI_EDUCACIONPADRE', 'FAMI_EDUCACIONMADRE',
#        'FAMI_TRABAJOLABORPADRE', 'FAMI_TRABAJOLABORMADRE',
#        'FAMI_TIENEINTERNET', 'FAMI_TIENESERVICIOTV', 'FAMI_TIENECOMPUTADOR',
#        'FAMI_TIENELAVADORA', 'FAMI_TIENEHORNOMICROOGAS', 'FAMI_TIENEAUTOMOVIL',
#        'FAMI_TIENEMOTOCICLETA', 'FAMI_TIENECONSOLAVIDEOJUEGOS',
#        'FAMI_NUMLIBROS', 'FAMI_COMELECHEDERIVADOS',
#        'FAMI_COMECARNEPESCADOHUEVO', 'FAMI_COMECEREALFRUTOSLEGUMBRE',
#        'FAMI_SITUACIONECONOMICA', 'ESTU_DEDICACIONLECTURADIARIA',
#        'ESTU_DEDICACIONINTERNET', 'ESTU_HORASSEMANATRABAJA',
# ...

# %%
df_columnas_a_comparar =df[[
       'PERCENTIL_LECTURA_CRITICA',
        'PERCENTIL_MATEMATICAS',
        'PERCENTIL_C_NATURALES',
        'PERCENTIL_SOCIALES_CIUDADANAS',
        ]]

# %%
df_columnas_a_comparar.head()
# Out:
#    PERCENTIL_LECTURA_CRITICA  PERCENTIL_MATEMATICAS  PERCENTIL_C_NATURALES  \
# 0                         33                     42                     15
# 1                         76                     88                     71
# 2                         91                     70                     29
# 3                         81                     60                     87
# 4                         85                     70                     74
#
#    PERCENTIL_SOCIALES_CIUDADANAS
# 0                              8
# 1                             83
# 2                             99
# 3                             99
# 4                             79

# %%
df_columnas_a_comparar.describe()
# Out:
#        PERCENTIL_LECTURA_CRITICA  PERCENTIL_MATEMATICAS  \
# count              546212.000000          546212.000000
# mean                   50.111151              50.110596
# std                    28.959257              28.947324
# min                     1.000000               1.000000
# 25%                    25.000000              25.000000
# 50%                    50.000000              50.000000
# 75%                    75.000000              75.000000
# max                   100.000000             100.000000
#
#        PERCENTIL_C_NATURALES  PERCENTIL_SOCIALES_CIUDADANAS
# count          546212.000000                  546212.000000
# mean               50.157646                      50.179648
# std                28.935705                      28.911682
# min                 1.000000                       1.000000
# 25%                25.000000                      25.000000
# 50%                50.000000                      50.000000
# ...

# %%
df_columnas_a_comparar.isnull().sum()
# Out:
# PERCENTIL_LECTURA_CRITICA        0
# PERCENTIL_MATEMATICAS            0
# PERCENTIL_C_NATURALES            0
# PERCENTIL_SOCIALES_CIUDADANAS    0
# dtype: int64

# %%
df.shape
# Out:
# (546212, 82)

# %%
df_columnas_a_comparar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546212 entries, 0 to 546211
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   PERCENTIL_LECTURA_CRITICA      546212 non-null  int64
#  1   PERCENTIL_MATEMATICAS          546212 non-null  int64
#  2   PERCENTIL_C_NATURALES          546212 non-null  int64
#  3   PERCENTIL_SOCIALES_CIUDADANAS  546212 non-null  int64
# dtypes: int64(4)
# memory usage: 16.7 MB

# %%
df_columnas_a_comparar.describe()
# Out:
#        PERCENTIL_LECTURA_CRITICA  PERCENTIL_MATEMATICAS  \
# count              546212.000000          546212.000000
# mean                   50.111151              50.110596
# std                    28.959257              28.947324
# min                     1.000000               1.000000
# 25%                    25.000000              25.000000
# 50%                    50.000000              50.000000
# 75%                    75.000000              75.000000
# max                   100.000000             100.000000
#
#        PERCENTIL_C_NATURALES  PERCENTIL_SOCIALES_CIUDADANAS
# count          546212.000000                  546212.000000
# mean               50.157646                      50.179648
# std                28.935705                      28.911682
# min                 1.000000                       1.000000
# 25%                25.000000                      25.000000
# 50%                50.000000                      50.000000
# ...

# %%
df_columnas_a_comparar.corr()
# Out:
#                                PERCENTIL_LECTURA_CRITICA  \
# PERCENTIL_LECTURA_CRITICA                       1.000000
# PERCENTIL_MATEMATICAS                           0.736170
# PERCENTIL_C_NATURALES                           0.747441
# PERCENTIL_SOCIALES_CIUDADANAS                   0.804070
#
#                                PERCENTIL_MATEMATICAS  PERCENTIL_C_NATURALES  \
# PERCENTIL_LECTURA_CRITICA                   0.736170               0.747441
# PERCENTIL_MATEMATICAS                       1.000000               0.797242
# PERCENTIL_C_NATURALES                       0.797242               1.000000
# PERCENTIL_SOCIALES_CIUDADANAS               0.723401               0.768294
#
#                                PERCENTIL_SOCIALES_CIUDADANAS
# PERCENTIL_LECTURA_CRITICA                           0.804070
# PERCENTIL_MATEMATICAS                               0.723401
# PERCENTIL_C_NATURALES                               0.768294
# ...

# %%
df_columnas_a_comparar.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(df_columnas_a_comparar.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# El análisis bivariado realizad muestra una correlación positiva entre los diferentes percentiles de las pruebas ICFES en Lectura Crítica, Matemáticas, Ciencias Naturales y Sociales Ciudadanas, con valores que oscilan entre 0.72 y 0.8. Esto indica que un buen rendimiento en una de estas áreas generalmente se asocia con un desempeño sólido en las demás. La correlación más fuerte, de 0.8, se observa entre Matemáticas y Ciencias Naturales, lo que sugiere una interrelación significativa entre estas áreas. Esta información es útil para enfocar estrategias de mejora educativa de manera integral.
